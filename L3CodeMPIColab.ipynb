# %% [markdown]
# <a href="https://colab.research.google.com/github/Liliakernou/Projet_questionnaire/blob/main/L3CodeMPIColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mpicxx -O2 -std=c++17 sujet.cxx -o nqueens

# %%
# !mpirun --allow-run-as-root --oversubscribe -np 6 ./nqueens 12
# Out:
# ...
#  Algorithme Génétique MPI — N Queens
# ...
# Selection  : Roulette
# Croisement : Multi-points
# Mutation   : Inversion / Insertion / Substitution
#
# Gen 0 | Best fitness = 64
#
# [EXEMPLE GEN 0]
# P1: 0 5 9 8 6 3 7 4 11 10 1 2
# P2: 9 1 6 8 5 0 3 7 11 2 4 10
# Enfant: 9 1 6 8 5 0 3 4 7 11 2 10
# ------------------------
#
# [EXEMPLE GEN 0]
# P1: 10 6 0 3 9 8 11 4 1 7 5 2
# P2: 11 0 10 2 9 1 8 6 4 3 5 7
# Enfant: 0 10 2 9 1 8 11 4 6 3 5 7
# ------------------------
#
# [EXEMPLE GEN 0]
# P1: 1 10 0 6 11 9 8 5 7 3 2 4
# P2: 9 4 11 8 0 5 7 2 6 3 1 10
# Enfant: 4 0 1 6 11 9 8 5 7 3 2 10
# ------------------------
#
# [EXEMPLE GEN 0]
# P1: 1 2 7 11 6 9 3 10 8 5 4 0
# P2: 8 10 1 7 9 5 2 3 11 4 0 6
# Enfant: 8 10 1 7 9 2 5 4 11 3 0 6
# ------------------------
#
# [EXEMPLE GEN 0]
# P1: 7 6 1 0 10 4 11 5 2 3 9 8
# P2: 10 6 7 8 2 5 11 9 0 3 4 1
# Enfant: 7 6 8 2 5 11 4 10 0 1 9 3
# ------------------------
#
# [EXEMPLE GEN 0]
# P1: 10 6 0 3 9 8 11 4 1 7 5 2
# P2: 0 5 9 8 6 3 7 4 11 10 1 2
# ...

# %% [markdown]
# # New Section
